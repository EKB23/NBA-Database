# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
import shutil
import time
# !pip install pandas
import pandas as pd
# !pip install unidecode
import unidecode

# %%
driver = webdriver.Chrome(
    executable_path="/Users/ericr/chromedriver_32/chromedriver"
    )
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_46748\2497404269.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(

# %%
years = list(range(1960, 2024))

# %%
team_stats_url = "https://www.basketball-reference.com/teams/BOS/{}.html"

for year in years:
    url = team_stats_url.format(year)
    
    driver.get(url)
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(15)
    
    with open("BOS/{}.html".format(year), "w+", encoding="utf-8") as f:
        f.write(driver.page_source)

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../BOS/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_per_game")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
per_game_stats = pd.concat(dfs)

# %%
per_game_stats.head()
# Out:
#    Rk        Player  Age   G  GS    MP   FG   FGA    FG%  3P  ...  ORB  DRB  \
# 0   1  Bill Russell   25  74 NaN  42.5  7.5  16.1  0.467 NaN  ...  NaN  NaN
# 1   2     Bob Cousy   31  75 NaN  34.5  7.6  19.7  0.384 NaN  ...  NaN  NaN
# 2   3  Tom Heinsohn   25  75 NaN  32.3  9.0  21.2  0.423 NaN  ...  NaN  NaN
# 3   4  Frank Ramsey   28  73 NaN  27.5  5.8  14.5  0.397 NaN  ...  NaN  NaN
# 4   5  Bill Sharman   33  71 NaN  27.0  7.9  17.3  0.456 NaN  ...  NaN  NaN
#
#     TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  24.0  3.7  NaN  NaN  NaN  2.8  18.2  1960
# 1   4.7  9.5  NaN  NaN  NaN  1.9  19.4  1960
# 2  10.6  2.3  NaN  NaN  NaN  3.7  21.7  1960
# 3   6.9  1.9  NaN  NaN  NaN  3.4  15.3  1960
# 4   3.7  2.0  NaN  NaN  NaN  2.2  19.3  1960
#
# [5 rows x 29 columns]

# %%
per_game_stats.tail()
# Out:
#     Rk             Player  Age   G   GS    MP   FG  FGA    FG%   3P  ...  ORB  \
# 13  14  Justin Champagnie   21   2  0.0  11.5  1.0  6.0  0.167  0.5  ...  1.0
# 14  15  Mfiondu Kabengele   25   4  0.0   9.0  0.5  1.8  0.286  0.0  ...  1.3
# 15  16        Noah Vonleh   27  23  1.0   7.4  0.5  1.0  0.458  0.0  ...  0.8
# 16  17         JD Davison   20  12  0.0   5.5  0.7  1.6  0.421  0.2  ...  0.2
# 17  18     Justin Jackson   27  23  0.0   4.7  0.3  1.2  0.259  0.2  ...  0.1
#
#     DRB  TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 13  1.0  2.0  1.5  0.5  0.0  0.0  0.5  2.5  2023
# 14  1.3  2.5  0.0  0.5  0.0  0.3  0.8  1.5  2023
# 15  1.3  2.1  0.3  0.1  0.3  0.5  1.5  1.1  2023
# 16  0.6  0.8  0.9  0.2  0.2  0.3  0.4  1.6  2023
# 17  0.7  0.7  0.4  0.2  0.2  0.1  0.3  0.9  2023
#
# [5 rows x 29 columns]

# %%
per_game_stats.to_csv("bos_per_game_stats.csv")

# %%
players = pd.read_csv("bos_per_game_stats.csv")
players.head()
from unidecode import unidecode
players['Player'] = players['Player'].apply(unidecode)
#players['Unnamed: 1'] = players['Unnamed: 1'].apply(unidecode)
players.to_csv("bos_per_game_stats.csv")

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../BOS/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_team_and_opponent")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
team_opponents_stats = pd.concat(dfs)

# %%
team_opponents_stats.head()
# Out:
#   Unnamed: 0     G   MP     FG    FGA    FG%     FT    FTA    FT%  ORB  ...  \
# 0       Team  75.0  NaN   3744   8971  0.417   1849   2519  0.734  NaN  ...
# 1     Team/G   NaN  NaN   49.9  119.6  0.417   24.7   33.6  0.734  NaN  ...
# 2    Lg Rank   NaN  NaN      1      1  3.000      7      8  4.000  NaN  ...
# 3  Year/Year   NaN  NaN  12.0%   6.1%  0.022  -9.6%  -5.6% -0.032  NaN  ...
# 4   Opponent  75.0  NaN    NaN    NaN    NaN    NaN    NaN    NaN  NaN  ...
#
#    Year  STL  BLK  TOV   3P  3PA 3P%   2P  2PA 2P%
# 0  1960  NaN  NaN  NaN  NaN  NaN NaN  NaN  NaN NaN
# 1  1960  NaN  NaN  NaN  NaN  NaN NaN  NaN  NaN NaN
# 2  1960  NaN  NaN  NaN  NaN  NaN NaN  NaN  NaN NaN
# 3  1960  NaN  NaN  NaN  NaN  NaN NaN  NaN  NaN NaN
# 4  1960  NaN  NaN  NaN  NaN  NaN NaN  NaN  NaN NaN
#
# [5 rows x 25 columns]

# %%
team_opponents_stats.tail()
# Out:
#    Unnamed: 0     G     MP    FG   FGA    FG%    FT   FTA    FT%    ORB  ...  \
# 3   Year/Year   NaN   0.4%  3.6%  1.5%  0.009  2.8%  3.3% -0.004  -7.8%  ...
# 4    Opponent  82.0  19980  3425  7394  0.463  1332  1733  0.769    799  ...
# 5  Opponent/G   NaN  243.7  41.8  90.2  0.463  16.2  21.1  0.769    9.7  ...
# 6     Lg Rank   NaN      1    13    24  5.000     2     4  3.000      8  ...
# 7   Year/Year   NaN   0.4%  9.2%  2.4%  0.029  0.6%  2.4% -0.014  -6.9%  ...
#
#    Year     STL     BLK    TOV     3P    3PA    3P%     2P    2PA    2P%
# 3  2023  -11.8%  -10.0%  -2.1%  21.2%  14.7%  0.020  -4.9%  -8.2%  0.019
# 4  2023     544     318   1040    954   2763  0.345   2471   4631  0.534
# 5  2023     6.6     3.9   12.7   11.6   33.7  0.345   30.1   56.5  0.534
# 6  2023       5       4     26      6     17  4.000     17     24  7.000
# 7  2023  -12.0%  -15.4%  -8.2%  -1.5%  -3.4%  0.006  14.0%   6.2%  0.036
#
# [5 rows x 25 columns]

# %%
team_opponents_stats.to_csv("bos_team_opponents_stats.csv")

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../BOS/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_totals")[0]
    player_df = pd.read_html(str(player_table))[0][:-1]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
player_df
# Out:
#       Rk             Player   Age   G    GS    MP   FG   FGA    FG%   3P  ...  \
# 0    1.0       Jayson Tatum  24.0  74  74.0  2732  727  1559  0.466  240  ...
# 1    2.0       Jaylen Brown  26.0  67  67.0  2405  679  1383  0.491  163  ...
# 2    3.0      Derrick White  28.0  82  70.0  2319  350   758  0.462  149  ...
# 3    4.0     Grant Williams  24.0  79  23.0  2045  216   476  0.454  115  ...
# 4    5.0       Marcus Smart  28.0  61  61.0  1957  250   602  0.415  115  ...
# 5    6.0         Al Horford  36.0  63  63.0  1922  228   479  0.476  145  ...
# 6    7.0    Malcolm Brogdon  30.0  67   0.0  1744  354   732  0.484  132  ...
# 7    8.0         Sam Hauser  25.0  80   8.0  1290  180   396  0.455  140  ...
# 8    9.0    Robert Williams  25.0  35  20.0   824  127   170  0.747    0  ...
# 9   10.0        Luke Kornet  27.0  69   0.0   804  113   170  0.665    3  ...
# 10  11.0   Payton Pritchard  25.0  48   3.0   643  101   245  0.412   56  ...
# ...

# %%
totals = pd.concat(dfs)

# %%
totals.head()
# Out:
#     Rk        Player   Age   G  GS      MP   FG   FGA    FG%  3P  ...  ORB  \
# 0  1.0  Bill Russell  25.0  74 NaN  3146.0  555  1189  0.467 NaN  ...  NaN
# 1  2.0     Bob Cousy  31.0  75 NaN  2588.0  568  1481  0.384 NaN  ...  NaN
# 2  3.0  Tom Heinsohn  25.0  75 NaN  2420.0  673  1590  0.423 NaN  ...  NaN
# 3  4.0  Frank Ramsey  28.0  73 NaN  2009.0  422  1062  0.397 NaN  ...  NaN
# 4  5.0  Bill Sharman  33.0  71 NaN  1916.0  559  1225  0.456 NaN  ...  NaN
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  NaN  1778  277  NaN  NaN  NaN  210  1350  1960
# 1  NaN   352  715  NaN  NaN  NaN  146  1455  1960
# 2  NaN   794  171  NaN  NaN  NaN  275  1629  1960
# 3  NaN   506  137  NaN  NaN  NaN  251  1117  1960
# 4  NaN   262  144  NaN  NaN  NaN  154  1370  1960
#
# [5 rows x 29 columns]

# %%
totals.tail()
# Out:
#       Rk             Player   Age   G   GS     MP  FG  FGA    FG%   3P  ...  \
# 13  14.0        Noah Vonleh  27.0  23  1.0  171.0  11   24  0.458  1.0  ...
# 14  15.0     Justin Jackson  27.0  23  0.0  107.0   7   27  0.259  5.0  ...
# 15  16.0         JD Davison  20.0  12  0.0   66.0   8   19  0.421  2.0  ...
# 16  17.0  Mfiondu Kabengele  25.0   4  0.0   36.0   2    7  0.286  0.0  ...
# 17  18.0  Justin Champagnie  21.0   2  0.0   23.0   2   12  0.167  1.0  ...
#
#      ORB   DRB  TRB  AST  STL  BLK   TOV  PF  PTS  Year
# 13  18.0  30.0   48    7  2.0  8.0  11.0  35   25  2023
# 14   2.0  15.0   17    9  4.0  4.0   2.0   7   20  2023
# 15   2.0   7.0    9   11  2.0  2.0   4.0   5   19  2023
# 16   5.0   5.0   10    0  2.0  0.0   1.0   3    6  2023
# 17   2.0   2.0    4    3  1.0  0.0   0.0   1    5  2023
#
# [5 rows x 29 columns]

# %%
totals.to_csv("bos_player_totals.csv")

# %%
players = pd.read_csv("bos_player_totals.csv")
players.head()
from unidecode import unidecode
players['Player'] = players['Player'].apply(unidecode)
#players['Unnamed: 1'] = players['Unnamed: 1'].apply(unidecode)
players.to_csv("bos_player_totals.csv")

# %%
years = list(range(2000, 2024))

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../BOS/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_salaries2")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
salaries = pd.concat(dfs)

# %%
salaries.head()
# Out:
#    Rk        Unnamed: 1      Salary  Year
# 0   1    Antoine Walker  $9,000,000  2000
# 1   2    Kenny Anderson  $6,680,000  2000
# 2   3  Vitaly Potapenko  $3,810,000  2000
# 3   4       Dana Barros  $3,500,000  2000
# 4   5     Eric Williams  $3,336,000  2000

# %%
salaries.tail()
# Out:
#     Rk         Unnamed: 1      Salary  Year
# 18  19         Sam Hauser  $1,637,966  2023
# 19  20      Marial Shayok  $1,637,966  2023
# 20  21        A.J. Reeves  $1,017,781  2023
# 21  22        Eric Demers  $1,017,781  2023
# 22  23  Demetrius Jackson     $92,857  2023

# %%
salaries.to_csv("bos_player_salaries.csv")

# %%
players = pd.read_csv("bos_player_salaries.csv")
players.head()
from unidecode import unidecode
#players['Player'] = players['Player'].apply(unidecode)
players['Unnamed: 1'] = players['Unnamed: 1'].apply(unidecode)
players.to_csv("bos_player_salaries.csv")
