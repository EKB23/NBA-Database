# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
import shutil
import time
# !pip install pandas
import pandas as pd
# !pip install unidecode
import unidecode

# %%
driver = webdriver.Chrome(
    executable_path="/Users/ericr/chromedriver_32/chromedriver"
    )
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_32308\2497404269.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(

# %%
years = list(range(1967, 2024))

# %%
team_stats_url = "https://www.basketball-reference.com/teams/CHI/{}.html"

for year in years:
    url = team_stats_url.format(year)
    
    driver.get(url)
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(15)
    
    with open("CHI/{}.html".format(year), "w+", encoding="utf-8") as f:
        f.write(driver.page_source)

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../CHI/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_per_game")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
per_game_stats = pd.concat(dfs)

# %%
per_game_stats.head()
# Out:
#    Rk         Player  Age   G  GS    MP   FG   FGA    FG%  3P  ...  ORB  DRB  \
# 0   1    Guy Rodgers   31  81 NaN  37.8  6.6  17.0  0.391 NaN  ...  NaN  NaN
# 1   2    Jerry Sloan   24  80 NaN  36.8  6.6  15.2  0.432 NaN  ...  NaN  NaN
# 2   3     Bob Boozer   29  80 NaN  30.6  6.7  13.8  0.487 NaN  ...  NaN  NaN
# 3   4  Erwin Mueller   22  80 NaN  26.7  5.3  12.0  0.441 NaN  ...  NaN  NaN
# 4   5      Don Kojis   28  78 NaN  21.2  4.2   9.9  0.426 NaN  ...  NaN  NaN
#
#    TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  4.3  11.2  NaN  NaN  NaN  3.0  18.0  1967
# 1  9.1   2.1  NaN  NaN  NaN  3.7  17.4  1967
# 2  8.5   1.1  NaN  NaN  NaN  2.7  18.0  1967
# 3  6.2   1.6  NaN  NaN  NaN  2.8  12.7  1967
# 4  6.1   0.9  NaN  NaN  NaN  2.6  10.2  1967
#
# [5 rows x 29 columns]

# %%
per_game_stats.tail()
# Out:
#     Rk           Player  Age   G   GS   MP   FG  FGA    FG%   3P  ...  ORB  \
# 13  14     Terry Taylor   23   5  0.0  7.2  1.8  2.0  0.900  0.2  ...  1.0
# 14  15      Dalen Terry   20  38  0.0  5.6  0.8  1.9  0.444  0.2  ...  0.3
# 15  16  Marko Simonovic   23   7  0.0  2.9  0.3  1.0  0.286  0.1  ...  0.1
# 16  17     Tony Bradley   25  12  0.0  2.8  0.5  1.0  0.500  0.3  ...  0.1
# 17  18     Malcolm Hill   27   5  0.0  1.8  0.4  0.8  0.500  0.2  ...  0.0
#
#     DRB  TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 13  0.6  1.6  0.0  0.0  0.2  0.0  0.4  4.0  2023
# 14  0.7  1.0  0.6  0.3  0.1  0.2  0.6  2.2  2023
# 15  0.1  0.3  0.0  0.0  0.0  0.0  0.7  0.9  2023
# 16  0.8  0.9  0.1  0.1  0.1  0.1  0.2  1.6  2023
# 17  0.6  0.6  0.0  0.0  0.0  0.0  0.2  1.0  2023
#
# [5 rows x 29 columns]

# %%
per_game_stats.to_csv("chi_per_game_stats.csv")

# %%
players = pd.read_csv("chi_per_game_stats.csv")
players.head()
from unidecode import unidecode
players['Player'] = players['Player'].apply(unidecode)
#players['Unnamed: 1'] = players['Unnamed: 1'].apply(unidecode)
players.to_csv("chi_per_game_stats.csv")

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../CHI/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_per_game")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
team_opponents_stats = pd.concat(dfs)

# %%
team_opponents_stats.head()
# Out:
#    Rk         Player  Age   G  GS    MP   FG   FGA    FG%  3P  ...  ORB  DRB  \
# 0   1    Guy Rodgers   31  81 NaN  37.8  6.6  17.0  0.391 NaN  ...  NaN  NaN
# 1   2    Jerry Sloan   24  80 NaN  36.8  6.6  15.2  0.432 NaN  ...  NaN  NaN
# 2   3     Bob Boozer   29  80 NaN  30.6  6.7  13.8  0.487 NaN  ...  NaN  NaN
# 3   4  Erwin Mueller   22  80 NaN  26.7  5.3  12.0  0.441 NaN  ...  NaN  NaN
# 4   5      Don Kojis   28  78 NaN  21.2  4.2   9.9  0.426 NaN  ...  NaN  NaN
#
#    TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  4.3  11.2  NaN  NaN  NaN  3.0  18.0  1967
# 1  9.1   2.1  NaN  NaN  NaN  3.7  17.4  1967
# 2  8.5   1.1  NaN  NaN  NaN  2.7  18.0  1967
# 3  6.2   1.6  NaN  NaN  NaN  2.8  12.7  1967
# 4  6.1   0.9  NaN  NaN  NaN  2.6  10.2  1967
#
# [5 rows x 29 columns]

# %%
team_opponents_stats.tail()
# Out:
#     Rk           Player  Age   G   GS   MP   FG  FGA    FG%   3P  ...  ORB  \
# 13  14     Terry Taylor   23   5  0.0  7.2  1.8  2.0  0.900  0.2  ...  1.0
# 14  15      Dalen Terry   20  38  0.0  5.6  0.8  1.9  0.444  0.2  ...  0.3
# 15  16  Marko Simonovic   23   7  0.0  2.9  0.3  1.0  0.286  0.1  ...  0.1
# 16  17     Tony Bradley   25  12  0.0  2.8  0.5  1.0  0.500  0.3  ...  0.1
# 17  18     Malcolm Hill   27   5  0.0  1.8  0.4  0.8  0.500  0.2  ...  0.0
#
#     DRB  TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 13  0.6  1.6  0.0  0.0  0.2  0.0  0.4  4.0  2023
# 14  0.7  1.0  0.6  0.3  0.1  0.2  0.6  2.2  2023
# 15  0.1  0.3  0.0  0.0  0.0  0.0  0.7  0.9  2023
# 16  0.8  0.9  0.1  0.1  0.1  0.1  0.2  1.6  2023
# 17  0.6  0.6  0.0  0.0  0.0  0.0  0.2  1.0  2023
#
# [5 rows x 29 columns]

# %%
team_opponents_stats.to_csv("chi_team_opponents_stats.csv")

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../CHI/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_totals")[0]
    player_df = pd.read_html(str(player_table))[0][:-1]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
totals = pd.concat(dfs)

# %%
totals.head()
# Out:
#     Rk         Player   Age   G  GS    MP   FG   FGA    FG%  3P  ...  ORB  \
# 0  1.0    Guy Rodgers  31.0  81 NaN  3063  538  1377  0.391 NaN  ...  NaN
# 1  2.0    Jerry Sloan  24.0  80 NaN  2942  525  1214  0.432 NaN  ...  NaN
# 2  3.0     Bob Boozer  29.0  80 NaN  2451  538  1104  0.487 NaN  ...  NaN
# 3  4.0  Erwin Mueller  22.0  80 NaN  2136  422   957  0.441 NaN  ...  NaN
# 4  5.0      Don Kojis  28.0  78 NaN  1655  329   773  0.426 NaN  ...  NaN
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 0  NaN  346  908  NaN  NaN  NaN  243  1459  1967
# 1  NaN  726  170  NaN  NaN  NaN  293  1390  1967
# 2  NaN  679   90  NaN  NaN  NaN  212  1436  1967
# 3  NaN  497  131  NaN  NaN  NaN  223  1015  1967
# 4  NaN  479   70  NaN  NaN  NaN  204   792  1967
#
# [5 rows x 29 columns]

# %%
totals.tail()
# Out:
#       Rk           Player   Age   G   GS  MP  FG  FGA    FG%   3P  ...  ORB  \
# 13  14.0     Carlik Jones  25.0   7  0.0  56   6   15  0.400  3.0  ...  1.0
# 14  15.0     Terry Taylor  23.0   5  0.0  36   9   10  0.900  1.0  ...  5.0
# 15  16.0     Tony Bradley  25.0  12  0.0  33   6   12  0.500  3.0  ...  1.0
# 16  17.0  Marko Simonovic  23.0   7  0.0  20   2    7  0.286  1.0  ...  1.0
# 17  18.0     Malcolm Hill  27.0   5  0.0   9   2    4  0.500  1.0  ...  0.0
#
#      DRB  TRB  AST  STL  BLK  TOV  PF  PTS  Year
# 13   4.0    5    6  2.0  0.0  2.0   2   20  2023
# 14   3.0    8    0  0.0  1.0  0.0   2   20  2023
# 15  10.0   11    1  1.0  1.0  1.0   2   19  2023
# 16   1.0    2    0  0.0  0.0  0.0   5    6  2023
# 17   3.0    3    0  0.0  0.0  0.0   1    5  2023
#
# [5 rows x 29 columns]

# %%
totals.to_csv("chi_player_totals.csv")

# %%
players = pd.read_csv("chi_player_totals.csv")
players.head()
from unidecode import unidecode
players['Player'] = players['Player'].apply(unidecode)
#players['Unnamed: 1'] = players['Unnamed: 1'].apply(unidecode)
players.to_csv("chi_player_totals.csv")

# %%
years = years = list(range(2000, 2024))

# %%
from bs4 import BeautifulSoup

dfs = []
for year in years:
    with open("../CHI/{}.html".format(year), encoding="utf-8") as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    player_table = soup.find_all(id="div_salaries2")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
salaries = pd.concat(dfs)

# %%
salaries.head()
# Out:
#    Rk       Unnamed: 1      Salary  Year
# 0   1      Will Perdue  $5,300,000  2000
# 1   2   Hersey Hawkins  $4,164,100  2000
# 2   3      John Starks  $4,000,000  2000
# 3   4      Elton Brand  $3,375,960  2000
# 4   5  Dickey Simpkins  $1,500,000  2000

# %%
salaries.tail()
# Out:
#     Rk             Unnamed: 1      Salary  Year
# 15  16            Ayo Dosunmu  $1,563,518  2023
# 16  17  Javon Freeman-Liberty  $1,017,781  2023
# 17  18         Ethan Thompson  $1,017,781  2023
# 18  19       Patrick Beverley    $506,508  2023
# 19  20           Carlik Jones    $357,717  2023

# %%
salaries.to_csv("chi_player_salaries.csv")

# %%
players = pd.read_csv("chi_player_salaries.csv")
players.head()
from unidecode import unidecode
#players['Player'] = players['Player'].apply(unidecode)
players['Unnamed: 1'] = players['Unnamed: 1'].apply(unidecode)
players.to_csv("chi_player_salaries.csv")
