# %%
import pandas as pd

player_fname = pd.read_csv(listofnames.csv)[0]
player_lname = pd.read_csv(listofnames.csv)[1]
letter = player_name[0][:1]
letter
url = ("https://www.basketball-reference.com/players/{letter}/{}{}01.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 player_fname = pd.read_csv(listofnames.csv)[0]
#       4 player_lname = pd.read_csv(listofnames.csv)[1]
#       5 letter = player_name[0][:1]
#
# NameError: name 'listofnames' is not defined

# %%
player_lname

# %%
import csv

def read_csv_column(filename, column_index):
    values = []  # Empty list to store the values
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            if len(row) > column_index:
                value = row[column_index]
                values.append(value)  # Append value to the list

    return values  # Return the list of values

# Usage example
filename = 'listofnames.csv'
column_index = 2  # Index of the column you want to read (0-based)
player_lname = read_csv_column(filename, column_index)
player_lname
# Out:
# ['James',
#  'Abdul-Jabbar',
#  'Malone',
#  'Bryant',
#  'Jordan',
#  'Nowitzki',
#  'Chamberlain',
#  'Erving',
#  'Malone',
#  "O'Neal",
#  'Anthony',
#  'Issel',
#  'Hayes',
#  'Olajuwon',
#  'Durant',
#  'Robertson',
#  'Wilkins',
#  'Gervin',
#  'Duncan',
#  'Pierce',
#  'Havlicek',
#  'Garnett',
#  'Carter',
#  'English',
#  'Barry',
#  'Miller',
#  'West',
#  'Gilmore',
#  'Ewing',
#  'Harden',
#  'Allen',
#  'Westbrook',
#  'Iverson',
#  'Barkley',
#  'Parish',
#  'Dantley',
#  'Wade',
#  'Baylor',
#  'Drexler',
#  'Payton',
#  'Bird',
#  'Paul',
#  'Curry',
#  'DeRozan',
#  'Greer',
#  'Bellamy',
#  'Gasol',
#  'Pettit',
#  'Robinson',
#  'Aldridge',
#  'Richmond',
#  'Johnson',
#  'Chambers',
#  'Jamison',
#  'Stockton',
#  'King',
#  'Robinson',
#  'Davis',
#  'Howard',
#  'Parker',
#  'Cummings',
#  'Crawford',
#  'Lillard',
#  'Lanier',
#  'Johnson',
#  'Goodrich',
#  'Theus',
#  'Ellis',
#  'Pippen',
#  'Terry',
#  'Walker',
#  'Thomas',
#  'McAdoo',
#  'Randolph',
# ...

# %%
def read_csv_column(filename, column_index):
    values = []  # Empty list to store the values
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            if len(row) > column_index:
                value = row[column_index]
                values.append(value)  # Append value to the list

    return values  # Return the list of values

# Usage example
filename = 'listofnames.csv'
column_index = 1  # Index of the column you want to read (0-based)
player_fname = read_csv_column(filename, column_index)

# %%
player_lname = [item.lower() for item in player_lname]

# %%
player_fname
# Out:
# ['lebron',
#  'kareem',
#  'karl',
#  'kobe',
#  'michael',
#  'dirk',
#  'wilt',
#  'julius',
#  'moses',
#  'shaquille',
#  'carmelo',
#  'dan',
#  'elvin',
#  'hakeem',
#  'kevin',
#  'oscar',
#  'dominique',
#  'george',
#  'tim',
#  'paul',
#  'john',
#  'kevin',
#  'vince',
#  'alex',
#  'rick',
#  'reggie',
#  'jerry',
#  'artis',
#  'patrick',
#  'james',
#  'ray',
#  'russell',
#  'allen',
#  'charles',
#  'robert',
#  'adrian',
#  'dwyane',
#  'elgin',
#  'clyde',
#  'gary',
#  'larry',
#  'chris',
#  'stephen',
#  'demar',
#  'hal',
#  'walt',
#  'pau',
#  'bob',
#  'david',
#  'lamarcus',
#  'mitch',
#  'joe',
#  'tom',
#  'antawn',
#  'john',
#  'bernard',
#  'clifford',
#  'walter',
#  'dwight',
#  'tony',
#  'terry',
#  'jamal',
#  'damian',
#  'bob',
#  'eddie',
#  'gail',
#  'reggie',
#  'dale',
#  'scottie',
#  'jason',
#  'chet',
#  'isiah',
#  'bob',
#  'zach',
#  'mark',
#  'dolph',
#  'tracy',
#  'glen',
#  'dave',
#  'world',
#  'calvin',
#  'lou',
#  'chris',
# ...

# %%
import pandas as pd

letter = player_lname[0][:1]
lname = player_lname[0][:5]
fname = player_fname[0][:2]
url = f"https://www.basketball-reference.com/players/{letter}/{lname}{fname}01.html"

# %%
url
# Out:
# 'https://www.basketball-reference.com/players/a/abdulka01.html'

# %%
# !pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = webdriver.Chrome(
    executable_path="/Users/ericr/chromedriver_32/chromedriver"
    )
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_2196\2497404269.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(

# %%
letter = player_lname[6][:1]
lname = player_lname[6][:5]
fname = player_fname[6][:2]
url = f"https://www.basketball-reference.com/players/{letter}/{lname}{fname}01.html"
    
    
driver.get(url)
driver.execute_script("window.scrollTo(1,10000)")
time.sleep(2)
    
with open("name/chamberlain.html", "w+", encoding="utf-8") as f:
    f.write(driver.page_source)

# %%
from bs4 import BeautifulSoup
with open("name/chamberlain.html", encoding="utf-8") as f:
    page = f.read()
    
soup = BeautifulSoup(page, 'html.parser')
name_table = soup.find_all(id="all_totals-playoffs_totals")[0]
name_df = pd.read_html(str(name_table))[0]

# %%
name_df
# Out:
#        Season   Age       Tm   Lg  Pos       G  GS       MP       FG      FGA  \
# 0     1959-60  23.0      PHW  NBA    C    72.0 NaN   3338.0   1065.0   2311.0
# 1     1960-61  24.0      PHW  NBA    C    79.0 NaN   3773.0   1251.0   2457.0
# 2     1961-62  25.0      PHW  NBA    C    80.0 NaN   3882.0   1597.0   3159.0
# 3     1962-63  26.0      SFW  NBA    C    80.0 NaN   3806.0   1463.0   2770.0
# 4     1963-64  27.0      SFW  NBA    C    80.0 NaN   3689.0   1204.0   2298.0
# 5     1964-65  28.0      TOT  NBA    C    73.0 NaN   3301.0   1063.0   2083.0
# 6     1964-65  28.0      SFW  NBA    C    38.0 NaN   1743.0    636.0   1275.0
# 7     1964-65  28.0      PHI  NBA    C    35.0 NaN   1558.0    427.0    808.0
# 8     1965-66  29.0      PHI  NBA    C    79.0 NaN   3737.0   1074.0   1990.0
# 9     1966-67  30.0      PHI  NBA    C    81.0 NaN   3682.0    785.0   1150.0
# 10    1967-68  31.0      PHI  NBA    C    82.0 NaN   3836.0    819.0   1377.0
# ...

# %%
name_df.to_csv("chamberlain.csv")
